# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Data source. [cyrrhosis.csv]

# %%
df = pd.read_csv("cyrrhosis.csv",encoding ='latin-1')

# %%
df.head()
# Out:
#    Latebirths   Wine_consumption  Liquor_consumption  Cirrhosis_death
# 0         33.2                 5                  30             41.2
# 1         33.8                 4                  41             31.7
# 2         40.6                 3                  38             39.4
# 3         39.2                 7                  48             57.5
# 4         45.5                11                  53             74.8

# %%
g = sns.FacetGrid(df, col="origin") 
g.map(plt.scatter, "horsepower", "mpg")

# %%
sns.pairplot(df)
