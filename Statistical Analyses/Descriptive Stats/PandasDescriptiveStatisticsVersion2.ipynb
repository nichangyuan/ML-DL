# %%
import pandas as pd
pd.set_option('display.max_rows', 1000)

# %% [markdown]
# ### Advantages using Pandas statistical functions <br>  Missing values are removed prior to computations

# %%
dfRate = pd.read_csv("World2017literacyRate.csv",encoding='latin1')

# %%
dfMortality = pd.read_csv("InfantMortalityGNI.csv",encoding='latin1')

# %%
dfRate.head()
# Out:
#                Country  Literacy_Rate
# 0              Albania             96
# 1              Algeria             73
# 2               Angola             70
# 3  Antigua and Barbuda             99
# 4            Argentina             98

# %%
dfMortality.head()
# Out:
#      Countries  GNI_PER_CAPITA  Infant_Mortality
# 0  Afghanistan           590.0              73.2
# 1      Albania          4290.0              14.0
# 2      Algeria          4800.0              25.5
# 3      Andorra             NaN               2.8
# 4       Angola          4040.0              86.5

# %% [markdown]
# ## Correlation with Pandas <br> ‘pearson’, ‘kendall’, ‘spearman’} default is pearson

# %% [markdown]
# ### Pearson correlation coefficient
# 1. Normal distribution
# 2. Linear assumption
# 3. No outliers in data

# %%
dfMortality.corr()
# Out:
#                   GNI_PER_CAPITA  Infant_Mortality
# GNI_PER_CAPITA          1.000000         -0.510167
# Infant_Mortality       -0.510167          1.000000

# %%
dfMortality.corr("pearson")
# Out:
#                   GNI_PER_CAPITA  Infant_Mortality
# GNI_PER_CAPITA          1.000000         -0.510167
# Infant_Mortality       -0.510167          1.000000

# %% [markdown]
# ### Spearman rank correlation
# 1. Is a nonparametric test
# 2. Assumption of a monotonic relationship.
# 3. Is less sensitive to outliers than Pearson's corr

# %%
dfMortality.corr("spearman")
# Out:
#                   GNI_PER_CAPITA  Infant_Mortality
# GNI_PER_CAPITA            1.0000           -0.8695
# Infant_Mortality         -0.8695            1.0000

# %% [markdown]
# ### Kendall tau rank
# 1. Is a nonparametric equivalent
# 2. Requires a monotonic relationship

# %%
dfMortality.corr("kendall")
# Out:
#                   GNI_PER_CAPITA  Infant_Mortality
# GNI_PER_CAPITA           1.00000          -0.67478
# Infant_Mortality        -0.67478           1.00000

# %% [markdown]
# ### Other Statistical functions available with PANDAS <br> Fisher’s definition of kurtosis (kurtosis of normal == 0.0

# %%
Count = dfRate['Literacy_Rate'].count()
Min   = dfRate['Literacy_Rate'].min()
Max   = dfRate['Literacy_Rate'].max()
Mode  = dfRate['Literacy_Rate'].mode()
SEM   = dfRate['Literacy_Rate'].sem()
Skew = dfRate['Literacy_Rate'].skew()
Kurtosis = dfRate['Literacy_Rate'].kurt()

# %%
print("The count of observations is: ",Count)
print("The minimum observation is: ",Min)
print("The maximum observation is: ",Max)
print("The mode is:",Mode)
print("The standard error of the mean is: ",SEM)
print("The kurtosis is: ", round(Kurtosis,2))
# Out:
# The count of observations is:  147
# The minimum observation is:  29
# The maximum observation is:  100
# The mode is: 0    100
# dtype: int64
# The standard error of the mean is:  1.5304295856
# The kurtosis is:  0.27

# %%
print("Mode is",Mode.iloc[0])
# Out:
# Mode is 100

# %% [markdown]
# ### Computing percentiles within Pandas

# %%
Percentile25th = dfRate['Literacy_Rate'].quantile(0.25,interpolation= 'linear')  # to match numpy percentile

# %%
Percentile25th
# Out:
# 71.0

# %%
dfRate.describe()
# Out:
#        Literacy_Rate
# count     147.000000
# mean       82.469388
# std        18.555473
# min        29.000000
# 25%        71.000000
# 50%        90.000000
# 75%        98.000000
# max       100.000000

# %%
dfRate.head()

# %% [markdown]
# ### Ranking data within Pandas <br> method : {‘average’, ‘min’, ‘max’, ‘first’, ‘dense’}
#
#         average: average rank of group
#         min: lowest rank in group
#         max: highest rank in group
#         first: ranks assigned in order they appear in the array
#         dense: like ‘min’, but rank always increases by 1 between groups

# %%
dfRate['Rank'] = dfRate['Literacy_Rate'].rank(method='min',ascending=False, pct=False)

# %%
dfRate.head(160)
# Out:
#                                        Country  Literacy_Rate   Rank
# 0                                      Albania             96   42.0
# 1                                      Algeria             73  104.0
# 2                                       Angola             70  112.0
# 3                          Antigua and Barbuda             99   17.0
# 4                                    Argentina             98   28.0
# 5                                      Armenia            100    1.0
# 6                                   Azerbaijan            100    1.0
# 7                                      Bahrain             92   65.0
# 8                                   Bangladesh             57  128.0
# 9                                      Belarus            100    1.0
# 10                                       Benin             42  140.0
# 11                                      Bhutan             53  136.0
# 12            Bolivia (Plurinational State of)             91   70.0
# 13                      Bosnia and Herzegovina             98   28.0
# 14                                    Botswana             84   92.0
# 15                                      Brazil             90   73.0
# 16                           Brunei Darussalam             95   47.0
# 17                                    Bulgaria             98   28.0
# 18                                Burkina Faso             29  146.0
# 19                                     Burundi             67  115.0
# 20                                    Cambodia             74  103.0
# 21                                    Cameroon             71  109.0
# 22                                  Cape Verde             84   92.0
# 23                                     CEE/CIS             98   28.0
# 24                    Central African Republic             56  130.0
# 25                                        Chad             34  144.0
# 26                                       Chile             99   17.0
# 27                                       China             94   52.0
# 28                                    Colombia             93   59.0
# 29                                     Comoros             75  100.0
# 30                                  Costa Rica             96   42.0
# 31                               Cote d'Ivoire             56  130.0
# 32                                     Croatia             99   17.0
# 33                                        Cuba            100    1.0
# 34                                      Cyprus             98   28.0
# 35       Democratic People's Republic of Korea            100    1.0
# 36            Democratic Republic of the Congo             67  115.0
# 37                          Dominican Republic             90   73.0
# 38                       East Asia and Pacific             94   52.0
# 39                 Eastern and Southern Africa             68  113.0
# 40                                     Ecuador             92   65.0
# 41                                       Egypt             72  108.0
# 42                                 El Salvador             84   92.0
# 43                           Equatorial Guinea             94   52.0
# 44                                     Eritrea             68  113.0
# 45                                     Estonia            100    1.0
# 46                                    Ethiopia             39  143.0
# 47                                       Gabon             88   84.0
# 48                                      Gambia             50  137.0
# 49                                     Georgia            100    1.0
# 50                                       Ghana             67  115.0
# 51                                      Greece             97   39.0
# 52                                   Guatemala             75  100.0
# 53                                      Guinea             41  142.0
# 54                               Guinea-Bissau             54  135.0
# 55                                       Haiti             49  139.0
# 56                                    Honduras             85   90.0
# 57                                     Hungary             99   17.0
# 58                                       India             63  120.0
# 59                                   Indonesia             93   59.0
# 60                  Iran (Islamic Republic of)             85   90.0
# 61                                        Iraq             78   97.0
# 62                                       Italy             99   17.0
# 63                                     Jamaica             87   85.0
